# %% [markdown]
# # Modulo 1
# ## Primeros pasos
# ----------------------------------------------------------------

# %% [markdown]
# ### Tu primer programa

# %%
from datetime import date
print(f'La fecha de hoy es: {date.today()}')
# Out:
# La fecha de hoy es: 2022-02-14

# %% [markdown]
# ### Construir un convertidor de unidades

# %%
## Convertidor de unidades entre parsecs y años luz
parsec = 11
lightyears = 0
print(f"{parsec} parsec is {3.26156 * parsec}")
# Out:
# 11 parsec is 35.877159999999996
