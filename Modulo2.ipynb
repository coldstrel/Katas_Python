# %% [markdown]
# ## Modulo 2
# #### Crear un entorno virtual.
# ----------------------------------------------------------------
#
# - Ejecucion del entorno virtual en la terminal.
#
# ![alt text](src/env_command.png)
#
# - Carpeta del entorno virtual en la terminal.
#
# ![alt text](src/dir_env_command.png)
#
# - Activacion del entorno virtual en la terminal.
#
# ![alt text](src/activacion_env.png)
#
# - Comando *Freeze pip*
#
# ![alt text](src/pip_freeze.png)
#
# - Instalacion de la bibilioteca dateutil.
#
# ![alt text](src/instalacion_biblioteca.png)
#
# - Desactivacion del entorno virtual.
#
# ![alt text](src/desactivacion_env.png)
